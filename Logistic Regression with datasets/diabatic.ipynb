# %%
import pandas as pd

# %%
path = '/content/drive/MyDrive/ML projects/Logistic/diabetes2.csv'
data = pd.read_csv(path)

# %%
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  ...  DiabetesPedigreeFunction  Age  Outcome
# 0            6      148             72  ...                     0.627   50        1
# 1            1       85             66  ...                     0.351   31        0
# 2            8      183             64  ...                     0.672   32        1
# 3            1       89             66  ...                     0.167   21        0
# 4            0      137             40  ...                     2.288   33        1
#
# [5 rows x 9 columns]

# %%
data.isnull().sum()
data.shape
# Out:
# (768, 9)

# %%
feature = data.iloc[:,0:7]
label = data.iloc[:,8]

# %%
from sklearn.model_selection import train_test_split
trainF,testF,trainL,testL= train_test_split(feature,label,test_size=.1)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
model.fit(trainF,trainL)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
predict = model.predict(testF)

# %%
from sklearn.metrics import confusion_matrix,plot_confusion_matrix,classification_report

# %%
cm = confusion_matrix(predict,testL)
report = classification_report(predict,testL,target_names=['diabetic','non diabetic'])
print(report)
# Out:
#               precision    recall  f1-score   support
#
#     diabetic       0.85      0.85      0.85        55
# non diabetic       0.64      0.64      0.64        22
#
#     accuracy                           0.79        77
#    macro avg       0.75      0.75      0.75        77
# weighted avg       0.79      0.79      0.79        77

# %%
plot_confusion_matrix(model,testF,testL)
